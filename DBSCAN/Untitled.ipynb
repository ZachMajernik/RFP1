# %%
import pandas as pd
import seaborn as sns

# %%
df1 = pd.read_csv('ad_details.csv')
df2 = pd.read_csv('ad_events.csv')
df3 = pd.read_csv('customer_profiles.csv')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   reward           10 non-null     int64
#  1   channels         10 non-null     object
#  2   required_amount  10 non-null     int64
#  3   duration (days)  10 non-null     int64
#  4   offer_type       10 non-null     object
#  5   ad id            10 non-null     object
# dtypes: int64(3), object(3)
# memory usage: 608.0+ bytes

# %%
df1.head(10)
# Out:
#    reward                              channels  required_amount  \
# 0      10         ['email', 'mobile', 'social']               10
# 1      10  ['web', 'email', 'mobile', 'social']               10
# 2       0            ['web', 'email', 'mobile']                0
# 3       5            ['web', 'email', 'mobile']                5
# 4       5                      ['web', 'email']               20
# 5       3  ['web', 'email', 'mobile', 'social']                7
# 6       2  ['web', 'email', 'mobile', 'social']               10
# 7       0         ['email', 'mobile', 'social']                0
# 8       5  ['web', 'email', 'mobile', 'social']                5
# 9       2            ['web', 'email', 'mobile']               10
#
#    duration (days)     offer_type                             ad id
# 0                7           bogo  ae264e3637204a6fb9bb56bc8210ddfd
# 1                5           bogo  4d5c57ea9a6940dd891ad53e9dbe8da0
# ...

# %%
df = pd.merge(df2, df3, left_on='customer', right_on='id')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 272762 entries, 0 to 272761
# Data columns (total 12 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   customer                           272762 non-null  object
#  1   event                              272762 non-null  object
#  2   event_info                         272762 non-null  object
#  3   time                               272762 non-null  int64
#  4   gender                             272762 non-null  object
#  5   age                                272762 non-null  int64
#  6   id                                 272762 non-null  object
#  7   became_member_on (year month day)  272762 non-null  int64
#  8   income                             272762 non-null  float64
#  9   ever_married                       272762 non-null  object
#  10  kids                               272762 non-null  int64
# ...

# %%
df.head()
# Out:
#                            customer            event  \
# 0  78afa995795e4d85b5d9ceeca43f5fef   offer received
# 1  78afa995795e4d85b5d9ceeca43f5fef     offer viewed
# 2  78afa995795e4d85b5d9ceeca43f5fef      transaction
# 3  78afa995795e4d85b5d9ceeca43f5fef  offer completed
# 4  78afa995795e4d85b5d9ceeca43f5fef      transaction
#
#                                           event_info  time gender  age  \
# 0   {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     0      F   75
# 1   {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     6      F   75
# 2                                  {'amount': 19.89}   132      F   75
# 3  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9...   132      F   75
# 4                                  {'amount': 17.78}   144      F   75
#
#                                  id  became_member_on (year month day)  \
# 0  78afa995795e4d85b5d9ceeca43f5fef                           20170509
# 1  78afa995795e4d85b5d9ceeca43f5fef                           20170509
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306534 entries, 0 to 306533
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   customer    306534 non-null  object
#  1   event       306534 non-null  object
#  2   event_info  306534 non-null  object
#  3   time        306534 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 9.4+ MB

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14825 entries, 0 to 14824
# Data columns (total 8 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             14825 non-null  object
#  1   age                                14825 non-null  int64
#  2   id                                 14825 non-null  object
#  3   became_member_on (year month day)  14825 non-null  int64
#  4   income                             14825 non-null  float64
#  5   ever_married                       14825 non-null  object
#  6   kids                               14825 non-null  int64
#  7   home_state                         14825 non-null  object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 926.7+ KB

# %%
df3.head(25)
# Out:
#    gender  age                                id  \
# 0       F   55  0610b486422d4921ae7d2bf64640c50b
# 1       F   75  78afa995795e4d85b5d9ceeca43f5fef
# 2       M   68  e2127556f4f64592b11af22de27a7932
# 3       M   65  389bc3fa690240e798340f5a15918d5c
# 4       M   58  2eeac8d8feae4a8cad5a6af0499a211d
# 5       F   61  aa4862eba776480b8bb9c68455b8c2e1
# 6       M   26  e12aeaf2d47d42479ea1c4ac3d8286c6
# 7       F   62  31dda685af34476cad5bc968bdb01c53
# 8       M   49  62cf5e10845442329191fc246e7bcea3
# 9       M   57  6445de3b47274c759400cd68131d91b4
# 10      F   61  a448667f336b42c9a66fc5ffd5d73772
# 11      F   40  440cf1fd7580490c971d8c651ed962af
# 12      M   64  4b0da7e80e5945209a1fdddfe813dbe0
# 13      F   78  c27e0d6ab72c455a8bb66d980963de60
# 14      M   42  f806632c011441378d4646567f357a21
# 15      F   56  d058f73bf8674a26a95227db098147b1
# 16      F   33  c6c9884912c645429f3333f912b55f44
# 17      F   46  7429a044884842d6862f516c38b1156f
# ...

# %%
len(df3['home_state'].unique())
# Out:
# 50

# %%
len(df3['kids'].unique())
# Out:
# 6

# %%
sns.scatterplot(data=df, x="home_state", y="age", hue="income")
# Out:
# <AxesSubplot:xlabel='home_state', ylabel='age'>
